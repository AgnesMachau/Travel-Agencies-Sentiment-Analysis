# %% [markdown]
# <a href="https://colab.research.google.com/github/AgnesMachau/Travel-Agencies-Sentiment-Analysis/blob/main/Travel_Agencies_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Installing snscrape
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 KB 2.7 MB/s eta 0:00:00
# ...

# %%
# Install the python version
# !apt-get install python3.7

# Select the version
# !python3.7 setup.py
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libpython3.7-minimal libpython3.7-stdlib python3.7-minimal
# Suggested packages:
#   python3.7-venv binfmt-support
# The following NEW packages will be installed:
#   libpython3.7-minimal libpython3.7-stdlib python3.7 python3.7-minimal
# 0 upgraded, 4 newly installed, 0 to remove and 21 not upgraded.
# Need to get 4,530 kB of archives.
# After this operation, 23.3 MB of additional disk space will be used.
# Get:1 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal/main amd64 libpython3.7-minimal amd64 3.7.16-1+focal1 [588 kB]
# Get:2 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal/main amd64 python3.7-minimal amd64 3.7.16-1+focal1 [1,808 kB]
# ...

# %%
# !pip3 install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /tmp/pip-req-build-24t3w0i3
#   Running command git clone --filter=blob:none --quiet https://github.com/JustAnotherArchivist/snscrape.git /tmp/pip-req-build-24t3w0i3
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit f329b69ed4022c4e8af5be8a07d4f5a4125bd8d9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for UNKNOWN: filename=UNKNOWN-0.5.0.20230114.dev31+gf329b69-py3-none-any.whl size=13563 sha256=192c4f25dd304afc7de2ace2bf1eecac5eaa74d4bf7a0b40ccbde5517b428275
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2d9fckdu/wheels/92/42/87/33fa9b18f7a75d02643a9ca3743339aec9be28c6796267c7d8
# Successfully built UNKNOWN
# ...

# %%
#Importing the relevant libraries
import snscrape.modules.twitter as sntwitter
import pandas as pd
import itertools
import os

# %% [markdown]
# #Data Mining

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter

# Initialize empty list to store data
tweets_list = []
#Scraping tweets that have tagged trippygotours
# Iterate through tweets
for tweet in sntwitter.TwitterSearchScraper('trippygotours since:2019-01-01 until:2022-12-31').get_items():
    # Extract relevant data from the tweet
    username = tweet.user.username
    content = tweet.content
    date = tweet.date
     # Store data in dictionary
    tweet_dict = {
        "Username": username,
        "Content": content,
        "Date": date
    }


    # Store data in dictionary
    tweet_dict = {
        "Username": username,
        "Content": content,
        "Date": date
    }

    # Add dictionary to list
    tweets_list.append(tweet_dict)

# Convert list of dictionaries to DataFrame
tweets_df = pd.DataFrame(tweets_list)
#Saving as a csv file
tweets_df.to_csv('trippy.csv', index=False)
#Previewing the first 20 rows
tweets_df.head(20)
# Out:
# <ipython-input-6-acaf2d413deb>:11: FutureWarning: content is deprecated, use rawContent instead
#   content = tweet.content
#          Username                                            Content  \
# 0   trippygotours  Vuka mwaka at the exclusive &amp; only camp in...
# 1   trippygotours  You deserve a nice staycation \n\nWhy not esca...
# 2   trippygotours  Catch the SGR train ride to the Taita Hills Sa...
# 3   trippygotours  DUBAI SHOPPING FESTIVAL 🎉\n\nIt's back, bigger...
# 4   trippygotours  A thrilling &amp; exciting experience you shou...
# 5   trippygotours  NEW YEAR IN MAASAI MARA\n\nTIPILIKWANI MARA CA...
# 6   trippygotours  @linahMVC These are the extra charges to carte...
# 7        linahMVC  @trippygotours What does, supplement 3000 pp p...
# 8   trippygotours  Adults Only Camp\n\nThe Cliff Nakuru is the pe...
# 9   trippygotours  Maasai Mara New Year Safari\n\nMara Serena Saf...
# 10  trippygotours  Begin the New Year at the pristine beaches of ...
# ...

# %%
tweets_df.head()
# Out:
#         Username                                            Content  \
# 0  trippygotours  Vuka mwaka at the exclusive &amp; only camp in...
# 1  trippygotours  You deserve a nice staycation \n\nWhy not esca...
# 2  trippygotours  Catch the SGR train ride to the Taita Hills Sa...
# 3  trippygotours  DUBAI SHOPPING FESTIVAL 🎉\n\nIt's back, bigger...
# 4  trippygotours  A thrilling &amp; exciting experience you shou...
#
#                        Date
# 0 2022-12-30 13:03:04+00:00
# 1 2022-12-30 11:51:54+00:00
# 2 2022-12-30 11:32:15+00:00
# 3 2022-12-30 07:51:23+00:00
# 4 2022-12-29 13:17:07+00:00

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter

# Initialize empty list to store data
tweets_list = []
#Scraping tweets that have tagged trippygotours
# Iterate through tweets
for tweet in sntwitter.TwitterSearchScraper('ETG_TRAVEL since:2019-01-01 until:2022-12-31').get_items():
    # Extract relevant data from the tweet
    username = tweet.user.username
    content = tweet.content
    date = tweet.date
     # Store data in dictionary
    tweet_dict = {
        "Username": username,
        "Content": content,
        "Date": date
    }


    # Store data in dictionary
    tweet_dict = {
        "Username": username,
        "Content": content,
        "Date": date
    }

    # Add dictionary to list
    tweets_list.append(tweet_dict)

# Convert list of dictionaries to DataFrame
tweets_df = pd.DataFrame(tweets_list)
#Saving as a csv file
tweets_df.to_csv('etg.csv.csv', index=False)
#Previewing the first 20 rows
tweets_df.head(20)
# Out:
# <ipython-input-8-c519aeebb57f>:11: FutureWarning: content is deprecated, use rawContent instead
#   content = tweet.content
#            Username                                            Content  \
# 0          saad_kkm  @Puke2Earn @joinMovEX @hdkdocunc @ETGtravel @f...
# 1   LunenburgFootb1  #15 Lunenburg (3-3) travels to #1 West Boylsto...
# 2      AFTAOfficial  What an aerial display of skill at #NTIA2022! ...
# 3       StockIdeas9  Making money is a good habit. What else could ...
# 4   TheBountyHunt17  Watch "Yungeen Gang - "Go To War" (Official Mu...
# 5   CarlMor20340998         @IAmENISA Travel around the world with ETG
# 6          TTGMedia  The boss of Sri Lanka specialist Experience Tr...
# 7    travelogafrica  Exit Express Travel Group, Enter Hemingways Tr...
# 8    CapitalFMKenya  Sixty-Five-year-old Travel Management Company,...
# 9   BiznaKeOfficial  Express Travel Group (ETG) Rebrands to Hemingw...
# ...

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter

# Initialize empty list to store data
tweets_list = []
#Scraping tweets that have tagged trippygotours
# Iterate through tweets
for tweet in sntwitter.TwitterSearchScraper('Bountifulsafari since:2019-01-01 until:2022-12-31').get_items():
    # Extract relevant data from the tweet
    username = tweet.user.username
    content = tweet.content
    date = tweet.date
     # Store data in dictionary
    tweet_dict = {
        "Username": username,
        "Content": content,
        "Date": date
    }


    # Store data in dictionary
    tweet_dict = {
        "Username": username,
        "Content": content,
        "Date": date
    }

    # Add dictionary to list
    tweets_list.append(tweet_dict)

# Convert list of dictionaries to DataFrame
tweets_df = pd.DataFrame(tweets_list)
#Saving as a csv file
tweets_df.to_csv('bountiful.csv', index=False)
#Previewing the first 20 rows
tweets_df.head(20)
# Out:
# <ipython-input-9-efe79d978239>:11: FutureWarning: content is deprecated, use rawContent instead
#   content = tweet.content
#            Username                                            Content  \
# 0         BkenBoris  @Bountifulsafari #Maandamano #Mbappe kitambo n...
# 1    BrendaWangui11  Thank you to @Bountifulsafari for the great op...
# 2          ZuruLink  I have never regretted using #influencers to m...
# 3         BkenBoris  Si mnitafutie Kazi nitoke ushago chang'aa itan...
# 4   Bountifulsafari  #youdeserveaholiday #bountifulexperience https...
# 5   Bountifulsafari  𝗦𝗼 𝗺𝗮𝗻𝘆 𝗽𝗹𝗮𝗰𝗲𝘀 𝘁𝗼 𝗲𝘅𝗽𝗹𝗼𝗿𝗲, 𝘀𝗼 𝗹𝗶𝘁𝘁𝗹𝗲 𝘁𝗶𝗺𝗲........
# 6   Bountifulsafari                #Travelling https://t.co/JlKes5q9Bl
# 7   Bountifulsafari  𝑾𝒆 𝒕𝒓𝒂𝒗𝒆𝒍 𝒏𝒐𝒕 𝒕𝒐 𝒆𝒔𝒄𝒂𝒑𝒆 𝒍𝒊𝒇𝒆💸, 𝒃𝒖𝒕 𝒇𝒐𝒓 𝒍𝒊𝒇𝒆 𝒏𝒐...
# 8   Bountifulsafari  𝗗𝗶𝗿𝗲𝗰𝘁 𝗹𝗶𝗻𝗲: \n📱Call/WhatsApp on \n☎0724840482...
# 9   Bountifulsafari  🏊🏿‍♂️𝗚𝗼𝗼𝗱 𝗺𝗼𝗿𝗻𝗶𝗻𝗴 𝗳𝗿𝗼𝗺 𝗗𝗶𝗮𝗻𝗶🏝\n\n💸From as low ...
# ...

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter

# Initialize empty list to store data
tweets_list = []
#Scraping tweets that have tagged trippygotours
# Iterate through tweets
for tweet in sntwitter.TwitterSearchScraper('ToursSatguru since:2019-01-01 until:2022-12-31').get_items():
    # Extract relevant data from the tweet
    username = tweet.user.username
    content = tweet.content
    date = tweet.date
     # Store data in dictionary
    tweet_dict = {
        "Username": username,
        "Content": content,
        "Date": date
    }


    # Store data in dictionary
    tweet_dict = {
        "Username": username,
        "Content": content,
        "Date": date
    }

    # Add dictionary to list
    tweets_list.append(tweet_dict)

# Convert list of dictionaries to DataFrame
tweets_df = pd.DataFrame(tweets_list)
#Saving as a csv file
tweets_df.to_csv('satguru.csv', index=False)
#Previewing the first 20 rows
tweets_df.head(20)
# Out:
# <ipython-input-10-6d21346c0771>:11: FutureWarning: content is deprecated, use rawContent instead
#   content = tweet.content
#         Username                                            Content  \
# 0   ToursSatguru  Explore the land of love, Spain with your love...
# 1   ToursSatguru  We wish you achieve happiness and prosperity i...
# 2   ToursSatguru  Let us #celebrate this day to maintain the exi...
# 3   ToursSatguru  Book your tour to Volcano National Park with a...
# 4   ToursSatguru  Explore wildlife reserves and national parks i...
# 5   ToursSatguru  Explore wildlife reserves and national parks i...
# 6   ToursSatguru  Explore Dubai with an exclusive shopping festi...
# 7   ToursSatguru  Explore Dubai with an exclusive shopping festi...
# 8   ToursSatguru  Discover different countries in the Mediterran...
# 9   ToursSatguru  Enjoy a cruise trip to the Mediterranean Sea w...
# 10  ToursSatguru  Let’s spread happiness and peace around the na...
# ...

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter

# Initialize empty list to store data
tweets_list = []
#Scraping tweets that have tagged trippygotours
# Iterate through tweets
for tweet in sntwitter.TwitterSearchScraper('BonfireSafaris since:2019-01-01 until:2022-12-31').get_items():
    # Extract relevant data from the tweet
    username = tweet.user.username
    content = tweet.content
    date = tweet.date
     # Store data in dictionary
    tweet_dict = {
        "Username": username,
        "Content": content,
        "Date": date
    }


    # Store data in dictionary
    tweet_dict = {
        "Username": username,
        "Content": content,
        "Date": date
    }

    # Add dictionary to list
    tweets_list.append(tweet_dict)

# Convert list of dictionaries to DataFrame
tweets_df = pd.DataFrame(tweets_list)
#Saving as a csv file
tweets_df.to_csv('bonfire.csv', index=False)
#Previewing the first 20 rows
tweets_df.head(20)
# Out:
# <ipython-input-11-5c234d68bfac>:11: FutureWarning: content is deprecated, use rawContent instead
#   content = tweet.content
#            Username                                            Content  \
# 0       NyonyiTours  Happy 2023 to all our esteemed customers, frie...
# 1    ChiefZamani001  @BonfireSafaris na try ku beat drugs mazee. Si...
# 2           g_njora  @Ressy_an @SportPesa @BonfireSafaris @MaasaiSa...
# 3     BballersBrand               @xSimella @BonfireSafaris Offcourse😎
# 4          xSimella  @BballersBrand @BonfireSafaris Is this convers...
# 5     BballersBrand  @xSimella @BonfireSafaris Well they ain't lots...
# 6          xSimella  @BballersBrand @BonfireSafaris Well that took ...
# 7     BballersBrand  @xSimella 6. All along she was a real bitch so...
# 8    BonfireSafaris  Vile tuko Hyped for 2023🔥😍 \nHave You Secured ...
# 9   Jammu_Redefined                          @Madam_PB @BonfireSafaris
# ...

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter

# Initialize empty list to store data
tweets_list = []
#Scraping tweets that have tagged trippygotours
# Iterate through tweets
for tweet in sntwitter.TwitterSearchScraper('Kikwetu1 since:2019-01-01 until:2022-12-31').get_items():
    # Extract relevant data from the tweet
    username = tweet.user.username
    content = tweet.content
    date = tweet.date
     # Store data in dictionary
    tweet_dict = {
        "Username": username,
        "Content": content,
        "Date": date
    }


    # Store data in dictionary
    tweet_dict = {
        "Username": username,
        "Content": content,
        "Date": date
    }

    # Add dictionary to list
    tweets_list.append(tweet_dict)

# Convert list of dictionaries to DataFrame
tweets_df = pd.DataFrame(tweets_list)
#Saving as a csv file
tweets_df.to_csv('kikwetu.csv', index=False)
#Previewing the first 20 rows
tweets_df.head(20)
# Out:
# <ipython-input-12-5f4ff2bf0503>:11: FutureWarning: content is deprecated, use rawContent instead
#   content = tweet.content
#     Username                                            Content  \
# 0   Kikwetu1  Masai Mara will never disappoint. Experience b...
# 1   Kikwetu1  Enjoy your African Safari Tour with Kikwetu Cu...
# 2   Kikwetu1  Great view point of the mountain @ Nairobi, Ke...
# 3   Kikwetu1  See this Instagram photo by @kikwetu_cultural_...
# 4   Kikwetu1  See this Instagram post by @kikwetu_cultural_a...
# 5   Kikwetu1  XXX 3 : the return of Xander cage https://t.co...
# 6   Kikwetu1  XXX 3 : the return of Xander cage https://t.co...
# 7   Kikwetu1  100 FREE Instagram Followers https://t.co/Mqvc...
# 8   Kikwetu1  Get 50K FREE Followers For Instagram - SocialE...
# 9   Kikwetu1  We take this opportunity to welcome you to the...
# 10  Kikwetu1  This season being a wonderful one and with lot...
# 11  Kikwetu1  2019 is here, you should take this opportunity...
# ...

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter

# Initialize empty list to store data
tweets_list = []
#Scraping tweets that have tagged trippygotours
# Iterate through tweets
for tweet in sntwitter.TwitterSearchScraper('Maasaisafaris since:2019-01-01 until:2022-12-31').get_items():
    # Extract relevant data from the tweet
    username = tweet.user.username
    content = tweet.content
    date = tweet.date
     # Store data in dictionary
    tweet_dict = {
        "Username": username,
        "Content": content,
        "Date": date
    }


    # Store data in dictionary
    tweet_dict = {
        "Username": username,
        "Content": content,
        "Date": date
    }

    # Add dictionary to list
    tweets_list.append(tweet_dict)

# Convert list of dictionaries to DataFrame
tweets_df = pd.DataFrame(tweets_list)
#Saving as a csv file
tweets_df.to_csv('maasai.csv', index=False)
#Previewing the first 20 rows
tweets_df.head(20)
# Out:
# <ipython-input-13-c692f480808a>:11: FutureWarning: content is deprecated, use rawContent instead
#   content = tweet.content
#            Username                                            Content  \
# 0           g_njora  @Ressy_an @SportPesa @BonfireSafaris @MaasaiSa...
# 1       jimmybonche  Merry Christmas from @MaasaiSafaris!\n#Tembeak...
# 2          rjaramba  @edgarwabwire_ @WaruiJohn2 @MaasaiSafaris Some...
# 3         Gathirwa4  @edgarwabwire_ @WaruiJohn2 @MaasaiSafaris http...
# 4     Musaudaily254       @WaruiJohn2 @edgarwabwire_ @MaasaiSafaris 😅😅
# 5       Kiatu_sacco  @edgarwabwire_ @WaruiJohn2 @MaasaiSafaris Wall...
# 6      PrinceIndah1  @edgarwabwire_ @WaruiJohn2 @MaasaiSafaris sus ...
# 7        ian_sande4  @edgarwabwire_ @WaruiJohn2 @MaasaiSafaris I am...
# 8    mwauragideon90  @edgarwabwire_ @WaruiJohn2 @MaasaiSafaris Eei😂...
# 9          BCherich  @AlvineNyash_ @edgarwabwire_ @WaruiJohn2 @Maas...
# ...

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter

# Initialize empty list to store data
tweets_list = []
#Scraping tweets that have tagged trippygotours
# Iterate through tweets
for tweet in sntwitter.TwitterSearchScraper('Pollmanskenya since:2019-01-01 until:2022-12-31').get_items():
    # Extract relevant data from the tweet
    username = tweet.user.username
    content = tweet.content
    date = tweet.date
     # Store data in dictionary
    tweet_dict = {
        "Username": username,
        "Content": content,
        "Date": date
    }


    # Store data in dictionary
    tweet_dict = {
        "Username": username,
        "Content": content,
        "Date": date
    }

    # Add dictionary to list
    tweets_list.append(tweet_dict)

# Convert list of dictionaries to DataFrame
tweets_df = pd.DataFrame(tweets_list)
#Saving as a csv file
tweets_df.to_csv('pollmans.csv', index=False)
#Previewing the first 20 rows
tweets_df.head(20)
# Out:
# <ipython-input-14-a8957eedc446>:11: FutureWarning: content is deprecated, use rawContent instead
#   content = tweet.content
#          Username                                            Content  \
# 0        Nania790             @PollmansKenya https://t.co/idJ17On2Xd
# 1      Ltimmins91  @KayTrot @PollmansKenya @emiratesholsuk Octobe...
# 2         KayTrot  @Ltimmins91 @PollmansKenya @emiratesholsuk Ken...
# 3      Ltimmins91  @KayTrot @PollmansKenya @emiratesholsuk I was ...
# 4         KayTrot  @Ltimmins91 @PollmansKenya @emiratesholsuk Tan...
# 5      Ltimmins91  Asante Sana, Kenya 🇰🇪. The most peaceful, frie...
# 6   PollmansKenya  Explore our Hand Picked Experiences created ju...
# 7   PollmansKenya  Fancy an active holiday?  Test your limits as ...
# 8   PollmansKenya  Laragai House is a family home built on Borana...
# 9   PollmansKenya  Have you heard of the Rhino River Camp?\nOne o...
# 10  PollmansKenya  Explore our Hand Picked Experiences created ju...
# ...

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter

# Initialize empty list to store data
tweets_list = []
#Scraping tweets that have tagged trippygotours
# Iterate through tweets
for tweet in sntwitter.TwitterSearchScraper('ajtourssafaris since:2019-01-01 until:2022-12-31').get_items():
    # Extract relevant data from the tweet
    username = tweet.user.username
    content = tweet.content
    date = tweet.date
     # Store data in dictionary
    tweet_dict = {
        "Username": username,
        "Content": content,
        "Date": date
    }


    # Store data in dictionary
    tweet_dict = {
        "Username": username,
        "Content": content,
        "Date": date
    }

    # Add dictionary to list
    tweets_list.append(tweet_dict)

# Convert list of dictionaries to DataFrame
tweets_df = pd.DataFrame(tweets_list)
#Saving as a csv file
tweets_df.to_csv('aj.csv', index=False)
#Previewing the first 20 rows
tweets_df.head(20)
# Out:
# <ipython-input-15-ec1404fa299e>:11: FutureWarning: content is deprecated, use rawContent instead
#   content = tweet.content
#           Username                                            Content  \
# 0   ajtourssafaris    Holiday homes in watamu https://t.co/rzkLhJvJN4
# 1   ajtourssafaris        Just posted a photo https://t.co/JBJPVY4tpu
# 2   ajtourssafaris  Watamu marinepark  holiday https://t.co/yKxf9b...
# 3   ajtourssafaris  Heading for deep sea fishing in watamu https:/...
# 4   ajtourssafaris        Just posted a photo https://t.co/slkd0TbbnR
# 5   ajtourssafaris    Holiday homes in watamu https://t.co/0ycUBAXyfp
# 6   ajtourssafaris        Just posted a photo https://t.co/waFo1fg6jC
# 7   ajtourssafaris      Welcome to masai mara https://t.co/mI1CW5sF1K
# 8   ajtourssafaris  Hells kitchen malindi...#marafa https://t.co/F...
# 9   ajtourssafaris  Dolphine watch at marine park watamu..amazing ...
# 10  ajtourssafaris  Berberque sea food lunch at sudi island after ...
# ...

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# #Merging all the csv files

# %%
import glob

# list all csv files only
csv_files = glob.glob('*.{}'.format('csv'))
csv_files
# Out:
# ['trippy.csv',
#  'kikwetu.csv',
#  'maasai.csv',
#  'bountiful.csv',
#  'pollmans.csv',
#  'satguru.csv',
#  'bonfire.csv',
#  'etg.csv.csv',
#  'aj.csv']

# %%
import pandas as pd

Tweets_df = pd.DataFrame()

# append the CSV files
for file in csv_files:
    df = pd.read_csv(file, lineterminator='\n')
    Tweets_df = Tweets_df.append(df, ignore_index=True)
#Previewing the first five rows of the combined dataset
Tweets_df.head()
# Out:
#         Username                                            Content  \
# 0  trippygotours  Vuka mwaka at the exclusive &amp; only camp in...
# 1  trippygotours  You deserve a nice staycation \n\nWhy not esca...
# 2  trippygotours  Catch the SGR train ride to the Taita Hills Sa...
# 3  trippygotours  DUBAI SHOPPING FESTIVAL 🎉\n\nIt's back, bigger...
# 4  trippygotours  A thrilling &amp; exciting experience you shou...
#
#                         Date
# 0  2022-12-30 13:03:04+00:00
# 1  2022-12-30 11:51:54+00:00
# 2  2022-12-30 11:32:15+00:00
# 3  2022-12-30 07:51:23+00:00
# 4  2022-12-29 13:17:07+00:00

# %%
#Previewing the last five rows of the dataset
Tweets_df.tail()
# Out:
#              Username                                            Content  \
# 23430  ajtourssafaris      Welcome to masai mara https://t.co/mI1CW5sF1K
# 23431  ajtourssafaris  Hells kitchen malindi...#marafa https://t.co/F...
# 23432  ajtourssafaris  Dolphine watch at marine park watamu..amazing ...
# 23433  ajtourssafaris  Berberque sea food lunch at sudi island after ...
# 23434  ajtourssafaris  Swimming with fish at watamu marine park #snor...
#
#                             Date
# 23430  2019-02-22 05:21:31+00:00
# 23431  2019-02-21 08:31:31+00:00
# 23432  2019-02-21 08:29:35+00:00
# 23433  2019-02-21 08:25:57+00:00
# 23434  2019-02-21 08:23:53+00:00

# %%
#Saving the merged csv file
Tweets_df.to_csv('TravelAgencies_df.csv')

# %% [markdown]
# #Data Exploration

# %%
Tweets_df = pd.read_csv('TravelAgencies_df.csv', lineterminator='\n')
#Previewing the first 5 rows of the dataset
Tweets_df.head()
# Out:
#    Unnamed: 0       Username  \
# 0           0  trippygotours
# 1           1  trippygotours
# 2           2  trippygotours
# 3           3  trippygotours
# 4           4  trippygotours
#
#                                              Content  \
# 0  Vuka mwaka at the exclusive &amp; only camp in...
# 1  You deserve a nice staycation \n\nWhy not esca...
# 2  Catch the SGR train ride to the Taita Hills Sa...
# 3  DUBAI SHOPPING FESTIVAL 🎉\n\nIt's back, bigger...
# 4  A thrilling &amp; exciting experience you shou...
#
#                         Date
# 0  2022-12-30 13:03:04+00:00
# 1  2022-12-30 11:51:54+00:00
# 2  2022-12-30 11:32:15+00:00
# 3  2022-12-30 07:51:23+00:00
# 4  2022-12-29 13:17:07+00:00

# %%
Tweets_df.columns
# Out:
# Index(['Unnamed: 0', 'Username', 'Content', 'Date'], dtype='object')

# %%
Tweets_df.head(100)
# Out:
#     Unnamed: 0       Username  \
# 0            0  trippygotours
# 1            1  trippygotours
# 2            2  trippygotours
# 3            3  trippygotours
# 4            4  trippygotours
# ..         ...            ...
# 95          95  trippygotours
# 96          96  trippygotours
# 97          97  trippygotours
# 98          98  trippygotours
# 99          99  trippygotours
#
#                                               Content  \
# 0   Vuka mwaka at the exclusive &amp; only camp in...
# 1   You deserve a nice staycation \n\nWhy not esca...
# 2   Catch the SGR train ride to the Taita Hills Sa...
# 3   DUBAI SHOPPING FESTIVAL 🎉\n\nIt's back, bigger...
# 4   A thrilling &amp; exciting experience you shou...
# ..                                                ...
# 95  Want to have a taste of luxury living in Malin...
# 96  Spend a memorable weekend at Elementaita!\n\nE...
# 97  A Christmas safari to Sarova Shaba Game Lodge....
# ...

# %%
#Checking the number of rows and columns in the dataset
Tweets_df.shape
# Out:
# (23435, 4)

# %%
#Checking the name of the columns
Tweets_df.columns
# Out:
# Index(['Unnamed: 0', 'Username', 'Content', 'Date'], dtype='object')

# %% [markdown]
# #Data Cleaning

# %%
from datetime import datetime
# Convert timestamp column to pandas datetime format
Tweets_df['Date']  = pd.to_datetime(Tweets_df['Date'])
# extract year, month, and day from datetime object
Tweets_df['Year'] = Tweets_df['Date'].dt.year
Tweets_df['Month']  = Tweets_df['Date'].dt.month
Tweets_df['Day']  = Tweets_df['Date'].dt.day

Tweets_df.head()
# Out:
#    Unnamed: 0       Username  \
# 0           0  trippygotours
# 1           1  trippygotours
# 2           2  trippygotours
# 3           3  trippygotours
# 4           4  trippygotours
#
#                                              Content  \
# 0  Vuka mwaka at the exclusive &amp; only camp in...
# 1  You deserve a nice staycation \n\nWhy not esca...
# 2  Catch the SGR train ride to the Taita Hills Sa...
# 3  DUBAI SHOPPING FESTIVAL 🎉\n\nIt's back, bigger...
# 4  A thrilling &amp; exciting experience you shou...
#
#                        Date  \
# 0 2022-12-30 13:03:04+00:00
# 1 2022-12-30 11:51:54+00:00
# 2 2022-12-30 11:32:15+00:00
# 3 2022-12-30 07:51:23+00:00
# 4 2022-12-29 13:17:07+00:00
#
#                                               scores  compound sentiment_type  \
# 0  {'neg': 0.0, 'neu': 0.951, 'pos': 0.049, 'comp...    0.1280       Positive
# 1  {'neg': 0.042, 'neu': 0.773, 'pos': 0.185, 'co...    0.7337       Positive
# ...

# %%
# create new column with extracted values
Tweets_df['amount'] = Tweets_df['Content'].str.extract(r'Ksh (\d+)').astype(float)
Tweets_df.head()

# %%
#Previewing the first five rows of the dataset to see whether the columns have been dropped
Tweets_df.head()
# Out:
#    Unnamed: 0       Username  \
# 0           0  trippygotours
# 1           1  trippygotours
# 2           2  trippygotours
# 3           3  trippygotours
# 4           4  trippygotours
#
#                                              Content  \
# 0  Vuka mwaka at the exclusive &amp; only camp in...
# 1  You deserve a nice staycation \n\nWhy not esca...
# 2  Catch the SGR train ride to the Taita Hills Sa...
# 3  DUBAI SHOPPING FESTIVAL 🎉\n\nIt's back, bigger...
# 4  A thrilling &amp; exciting experience you shou...
#
#                         Date
# 0  2022-12-30 13:03:04+00:00
# 1  2022-12-30 11:51:54+00:00
# 2  2022-12-30 11:32:15+00:00
# 3  2022-12-30 07:51:23+00:00
# 4  2022-12-29 13:17:07+00:00

# %%
Tweets_df.tail()
# Out:
#        Unnamed: 0        Username  \
# 23430       23430  ajtourssafaris
# 23431       23431  ajtourssafaris
# 23432       23432  ajtourssafaris
# 23433       23433  ajtourssafaris
# 23434       23434  ajtourssafaris
#
#                                                  Content  \
# 23430      Welcome to masai mara https://t.co/mI1CW5sF1K
# 23431  Hells kitchen malindi...#marafa https://t.co/F...
# 23432  Dolphine watch at marine park watamu..amazing ...
# 23433  Berberque sea food lunch at sudi island after ...
# 23434  Swimming with fish at watamu marine park #snor...
#
#                             Date
# 23430  2019-02-22 05:21:31+00:00
# 23431  2019-02-21 08:31:31+00:00
# 23432  2019-02-21 08:29:35+00:00
# 23433  2019-02-21 08:25:57+00:00
# 23434  2019-02-21 08:23:53+00:00

# %% [markdown]
# #Sentiment Analysis

# %% [markdown]
# Fetch Sentiments Using NTLK Sentiment analyzer(Vader)

# %%
#Importing the relevant libraries
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %% [markdown]
# Now we’ll add columns to the original DataFrame to store polarity_score dictionaries, extracted compound scores, and new labels derived from the compound score. The sentiments in this method will be classified into negative, positive and, neutral ratio.

# %%
Tweets_df['Content'] = Tweets_df['Content'].astype(str)

# %%
Tweets_df['scores'] = Tweets_df['Content'].apply(lambda Description: sid.polarity_scores(Description))
Tweets_df.head()
# Out:
#    Unnamed: 0       Username  \
# 0           0  trippygotours
# 1           1  trippygotours
# 2           2  trippygotours
# 3           3  trippygotours
# 4           4  trippygotours
#
#                                              Content  \
# 0  Vuka mwaka at the exclusive &amp; only camp in...
# 1  You deserve a nice staycation \n\nWhy not esca...
# 2  Catch the SGR train ride to the Taita Hills Sa...
# 3  DUBAI SHOPPING FESTIVAL 🎉\n\nIt's back, bigger...
# 4  A thrilling &amp; exciting experience you shou...
#
#                         Date  \
# 0  2022-12-30 13:03:04+00:00
# 1  2022-12-30 11:51:54+00:00
# 2  2022-12-30 11:32:15+00:00
# 3  2022-12-30 07:51:23+00:00
# 4  2022-12-29 13:17:07+00:00
#
#                                               scores
# 0  {'neg': 0.0, 'neu': 0.951, 'pos': 0.049, 'comp...
# 1  {'neg': 0.042, 'neu': 0.773, 'pos': 0.185, 'co...
# 2  {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'comp...
# 3  {'neg': 0.0, 'neu': 0.57, 'pos': 0.43, 'compou...
# ...

# %%
Tweets_df.tail(100)
# Out:
#        Unnamed: 0        Username  \
# 23335       23335         jboyded
# 23336       23336        AnimaeOK
# 23337       23337         jboyded
# 23338       23338     TJ__Brown__
# 23339       23339     TJ__Brown__
# ...           ...             ...
# 23430       23430  ajtourssafaris
# 23431       23431  ajtourssafaris
# 23432       23432  ajtourssafaris
# 23433       23433  ajtourssafaris
# 23434       23434  ajtourssafaris
#
#                                                  Content  \
# 23335  @AnthonyCole68 @AliCupper What actually came o...
# 23336  @ETG_TRAVEL @jboyded @si_jackson @pauldutton19...
# 23337  @SepticFinger @ETG_TRAVEL @si_jackson @pauldut...
# 23338  @ETG_TRAVEL @si_jackson @All_Eskat @pauldutton...
# 23339             @GayeCrispin @ETG_TRAVEL 👏👏👏👏👏👏👏👏👏👏👏👏👏
# ...                                                  ...
# 23430      Welcome to masai mara https://t.co/mI1CW5sF1K
# 23431  Hells kitchen malindi...#marafa https://t.co/F...
# ...

# %%
# Compound score evaluation and giving the sentiments labels

Tweets_df['compound'] = Tweets_df['scores'].apply(lambda score_dict: score_dict['compound'])
Tweets_df['sentiment_type']=''
Tweets_df.loc[Tweets_df.compound>0,'sentiment_type']='Positive'
Tweets_df.loc[Tweets_df.compound==0,'sentiment_type']='Neutral'
Tweets_df.loc[Tweets_df.compound<0,'sentiment_type']='Negative'

# %%
#Previewing the last 50 rows
Tweets_df.tail(50)
# Out:
#        Unnamed: 0         Username  \
# 23385       23385           APSETG
# 23386       23386  Nick_theking507
# 23387       23387     ebook_travel
# 23388       23388     TalkBrandCap
# 23389       23389          ExpTrav
# 23390       23390      hwaystravel
# 23391       23391           ritu55
# 23392       23392      hwaystravel
# 23393       23393      hwaystravel
# 23394       23394           etg_kw
# 23395       23395      hwaystravel
# 23396       23396      hwaystravel
# 23397       23397      hwaystravel
# 23398       23398      hwaystravel
# 23399       23399         ExtraT_G
# 23400       23400     ebook_travel
# 23401       23401      hwaystravel
# 23402       23402          BusTrav
# 23403       23403    AskChefDennis
# 23404       23404     ebook_travel
# 23405       23405     ebook_travel
# 23406       23406     ebook_travel
# 23407       23407     ebook_travel
# 23408       23408     ebook_travel
# 23409       23409     ebook_travel
# ...

# %%
# Displaying the sentiments on a countplot

import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x = 'sentiment_type',data = Tweets_df,palette='Set1' )
plt.title('Countplot of Sentiments in data')
plt.figure(figsize=(10,10),dpi=100)
plt.show()

# %%
# Frequency table
Tweets_df.sentiment_type.value_counts()
# Out:
# Positive    11720
# Neutral      9934
# Negative     1781
# Name: sentiment_type, dtype: int64

# %% [markdown]
# #Data Pre - Processing

# %% [markdown]
# Text Pre-Processing using key words

# %%
def remove_pattern(text, pattern_regex):
    r = re.findall(pattern_regex, text)
    for i in r:
        text = re.sub(i, '', text)

    return text

# %%
import numpy as np
import re
re.compile('<title>(.*)</title>')
# # We are keeping cleaned tweets in a new column called 'tidy_tweets'
Tweets_df['tidy_tweets'] = np.vectorize(remove_pattern)(Tweets_df['Content'],"@[\w]*")
Tweets_df.head(10)
# Out:
#    Unnamed: 0       Username  \
# 0           0  trippygotours
# 1           1  trippygotours
# 2           2  trippygotours
# 3           3  trippygotours
# 4           4  trippygotours
# 5           5  trippygotours
# 6           6  trippygotours
# 7           7       linahMVC
# 8           8  trippygotours
# 9           9  trippygotours
#
#                                              Content  \
# 0  Vuka mwaka at the exclusive &amp; only camp in...
# 1  You deserve a nice staycation \n\nWhy not esca...
# 2  Catch the SGR train ride to the Taita Hills Sa...
# 3  DUBAI SHOPPING FESTIVAL 🎉\n\nIt's back, bigger...
# 4  A thrilling &amp; exciting experience you shou...
# 5  NEW YEAR IN MAASAI MARA\n\nTIPILIKWANI MARA CA...
# 6  @linahMVC These are the extra charges to carte...
# 7  @trippygotours What does, supplement 3000 pp p...
# 8  Adults Only Camp\n\nThe Cliff Nakuru is the pe...
# 9  Maasai Mara New Year Safari\n\nMara Serena Saf...
#
#                         Date  \
# ...

# %%
# # Removing links (http | https)

cleaned_tweets = []

for index, row in Tweets_df.iterrows():
    # Here we are filtering out all the words that contains link
    words_without_links = [word for word in row.tidy_tweets.split() if 'http' not in word]
    cleaned_tweets.append(' '.join(words_without_links))

Tweets_df['tidy_tweets'] = cleaned_tweets
Tweets_df.head(10)
# Out:
#    Unnamed: 0       Username  \
# 0           0  trippygotours
# 1           1  trippygotours
# 2           2  trippygotours
# 3           3  trippygotours
# 4           4  trippygotours
# 5           5  trippygotours
# 6           6  trippygotours
# 7           7       linahMVC
# 8           8  trippygotours
# 9           9  trippygotours
#
#                                              Content  \
# 0  Vuka mwaka at the exclusive &amp; only camp in...
# 1  You deserve a nice staycation \n\nWhy not esca...
# 2  Catch the SGR train ride to the Taita Hills Sa...
# 3  DUBAI SHOPPING FESTIVAL 🎉\n\nIt's back, bigger...
# 4  A thrilling &amp; exciting experience you shou...
# 5  NEW YEAR IN MAASAI MARA\n\nTIPILIKWANI MARA CA...
# 6  @linahMVC These are the extra charges to carte...
# 7  @trippygotours What does, supplement 3000 pp p...
# 8  Adults Only Camp\n\nThe Cliff Nakuru is the pe...
# 9  Maasai Mara New Year Safari\n\nMara Serena Saf...
#
#                         Date  \
# ...

# %%
# # Removing tweets with empty text
Tweets_df = Tweets_df[Tweets_df['tidy_tweets']!='']
Tweets_df.head(5)
# Out:
#    Unnamed: 0       Username  \
# 0           0  trippygotours
# 1           1  trippygotours
# 2           2  trippygotours
# 3           3  trippygotours
# 4           4  trippygotours
#
#                                              Content  \
# 0  Vuka mwaka at the exclusive &amp; only camp in...
# 1  You deserve a nice staycation \n\nWhy not esca...
# 2  Catch the SGR train ride to the Taita Hills Sa...
# 3  DUBAI SHOPPING FESTIVAL 🎉\n\nIt's back, bigger...
# 4  A thrilling &amp; exciting experience you shou...
#
#                         Date  \
# 0  2022-12-30 13:03:04+00:00
# 1  2022-12-30 11:51:54+00:00
# 2  2022-12-30 11:32:15+00:00
# 3  2022-12-30 07:51:23+00:00
# 4  2022-12-29 13:17:07+00:00
#
#                                               scores  compound sentiment_type  \
# 0  {'neg': 0.0, 'neu': 0.951, 'pos': 0.049, 'comp...    0.1280       Positive
# 1  {'neg': 0.042, 'neu': 0.773, 'pos': 0.185, 'co...    0.7337       Positive
# ...

# %%
# # Drop duplicate rows

Tweets_df.drop_duplicates(subset=['tidy_tweets'], keep=False)
Tweets_df.head(1)
# Out:
#    Unnamed: 0       Username  \
# 0           0  trippygotours
#
#                                              Content  \
# 0  Vuka mwaka at the exclusive &amp; only camp in...
#
#                         Date  \
# 0  2022-12-30 13:03:04+00:00
#
#                                               scores  compound sentiment_type  \
# 0  {'neg': 0.0, 'neu': 0.951, 'pos': 0.049, 'comp...     0.128       Positive
#
#                                          tidy_tweets
# 0  Vuka mwaka at the exclusive &amp; only camp in...

# %%
# Resetting index
# It seems that our index needs to be reset, since after removal of some rows, some index values are missing,
#  which may cause problem in future operations.

Tweets_df = Tweets_df.reset_index(drop=True)
Tweets_df.head(1)
# Out:
#    Unnamed: 0       Username  \
# 0           0  trippygotours
#
#                                              Content  \
# 0  Vuka mwaka at the exclusive &amp; only camp in...
#
#                         Date  \
# 0  2022-12-30 13:03:04+00:00
#
#                                               scores  compound sentiment_type  \
# 0  {'neg': 0.0, 'neu': 0.951, 'pos': 0.049, 'comp...     0.128       Positive
#
#                                          tidy_tweets
# 0  Vuka mwaka at the exclusive &amp; only camp in...

# %% [markdown]
# Removing Punctuations, Numbers and Special characters This step should not be followed if we also want to do sentiment analysis on key phrases as well, because semantic meaning in a sentence needs to be present. So here we will create one additional column 'absolute_tidy_tweets' which will contain absolute tidy words which can be further used for sentiment analysis on key words.

# %%
Tweets_df['absolute_tidy_tweets'] = Tweets_df['tidy_tweets'].str.replace("[^a-zA-Z#@ ]", "")
# Out:
# <ipython-input-42-34bc3abaf56f>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   Tweets_df['absolute_tidy_tweets'] = Tweets_df['tidy_tweets'].str.replace("[^a-zA-Z#@ ]", "")

# %%
Tweets_df.head()
# Out:
#    Unnamed: 0       Username  \
# 0           0  trippygotours
# 1           1  trippygotours
# 2           2  trippygotours
# 3           3  trippygotours
# 4           4  trippygotours
#
#                                              Content  \
# 0  Vuka mwaka at the exclusive &amp; only camp in...
# 1  You deserve a nice staycation \n\nWhy not esca...
# 2  Catch the SGR train ride to the Taita Hills Sa...
# 3  DUBAI SHOPPING FESTIVAL 🎉\n\nIt's back, bigger...
# 4  A thrilling &amp; exciting experience you shou...
#
#                         Date  \
# 0  2022-12-30 13:03:04+00:00
# 1  2022-12-30 11:51:54+00:00
# 2  2022-12-30 11:32:15+00:00
# 3  2022-12-30 07:51:23+00:00
# 4  2022-12-29 13:17:07+00:00
#
#                                               scores  compound sentiment_type  \
# 0  {'neg': 0.0, 'neu': 0.951, 'pos': 0.049, 'comp...    0.1280       Positive
# 1  {'neg': 0.042, 'neu': 0.773, 'pos': 0.185, 'co...    0.7337       Positive
# ...

# %% [markdown]
# Removing Stop words With the same reason we mentioned above, we won't perform this on 'tidy_tweets' column, because it needs to be used for key_phrases sentiment analysis.

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stopwords_set = set(stopwords.words("english"))
cleaned_tweets = []

for index, row in Tweets_df.iterrows():

    # filerting out all the
    words_without_stopwords = [word for word in row.absolute_tidy_tweets.split() if not word in stopwords_set and '#' not in word.lower()]

    # finally creating tweets list of tuples containing stopwords(list) and sentimentType
    cleaned_tweets.append(' '.join(words_without_stopwords))

Tweets_df['absolute_tidy_tweets'] = cleaned_tweets
Tweets_df.head(10)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#    Unnamed: 0       Username  \
# 0           0  trippygotours
# 1           1  trippygotours
# 2           2  trippygotours
# 3           3  trippygotours
# 4           4  trippygotours
# 5           5  trippygotours
# 6           6  trippygotours
# 7           7       linahMVC
# 8           8  trippygotours
# 9           9  trippygotours
#
#                                              Content  \
# 0  Vuka mwaka at the exclusive &amp; only camp in...
# 1  You deserve a nice staycation \n\nWhy not esca...
# 2  Catch the SGR train ride to the Taita Hills Sa...
# 3  DUBAI SHOPPING FESTIVAL 🎉\n\nIt's back, bigger...
# 4  A thrilling &amp; exciting experience you shou...
# 5  NEW YEAR IN MAASAI MARA\n\nTIPILIKWANI MARA CA...
# 6  @linahMVC These are the extra charges to carte...
# 7  @trippygotours What does, supplement 3000 pp p...
# ...

# %% [markdown]
# Tokenize 'absolute_tidy_tweets'

# %%
tokenized_tweet = Tweets_df['absolute_tidy_tweets'].apply(lambda x: x.split())
tokenized_tweet.head()
# Out:
# 0    [Vuka, mwaka, exclusive, amp, camp, inside, Na...
# 1    [You, deserve, nice, staycation, Why, escape, ...
# 2    [Catch, SGR, train, ride, Taita, Hills, Safari...
# 3    [DUBAI, SHOPPING, FESTIVAL, Its, back, bigger,...
# 4    [A, thrilling, amp, exciting, experience, tick...
# Name: absolute_tidy_tweets, dtype: object

# %% [markdown]
# Converting words to Lemma

# %%
import nltk
nltk.download('all')
from nltk.stem import PorterStemmer, WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
word_lemmatizer = WordNetLemmatizer()

tokenized_tweet = tokenized_tweet.apply(lambda x: [word_lemmatizer.lemmatize(i) for i in x])
tokenized_tweet.head()
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# ...

# %% [markdown]
# Joining all tokens into sentences

# %%
for i, tokens in enumerate(tokenized_tweet):
    tokenized_tweet[i] = ' '.join(tokens)

Tweets_df['absolute_tidy_tweets'] = tokenized_tweet
Tweets_df.head(10)
# Out:
#    Unnamed: 0       Username  \
# 0           0  trippygotours
# 1           1  trippygotours
# 2           2  trippygotours
# 3           3  trippygotours
# 4           4  trippygotours
# 5           5  trippygotours
# 6           6  trippygotours
# 7           7       linahMVC
# 8           8  trippygotours
# 9           9  trippygotours
#
#                                              Content  \
# 0  Vuka mwaka at the exclusive &amp; only camp in...
# 1  You deserve a nice staycation \n\nWhy not esca...
# 2  Catch the SGR train ride to the Taita Hills Sa...
# 3  DUBAI SHOPPING FESTIVAL 🎉\n\nIt's back, bigger...
# 4  A thrilling &amp; exciting experience you shou...
# 5  NEW YEAR IN MAASAI MARA\n\nTIPILIKWANI MARA CA...
# 6  @linahMVC These are the extra charges to carte...
# 7  @trippygotours What does, supplement 3000 pp p...
# 8  Adults Only Camp\n\nThe Cliff Nakuru is the pe...
# 9  Maasai Mara New Year Safari\n\nMara Serena Saf...
#
#                         Date  \
# ...

# %% [markdown]
# Key Phrases

# %% [markdown]
# Pre-processing 'Key Phrases'

# %%
class PhraseExtractHelper(object):
    def __init__(self):
        self.lemmatizer = nltk.WordNetLemmatizer()
        self.stemmer = nltk.stem.porter.PorterStemmer()

    def leaves(self, tree):
        """Finds NP (nounphrase) leaf nodes of a chunk tree."""
        for subtree in tree.subtrees(filter = lambda t: t.label()=='NP'):
            yield subtree.leaves()

    def normalise(self, word):
        """Normalises words to lowercase and stems and lemmatizes it."""
        word = word.lower()
        # word = self.stemmer.stem_word(word) # We will loose the exact meaning of the word
        word = self.lemmatizer.lemmatize(word)
        return word

    def acceptable_word(self, word):
        """Checks conditions for acceptable word: length, stopword. We can increase the length if we want to consider large phrase"""
        accepted = bool(3 <= len(word) <= 40
            and word.lower() not in stopwords_set
            and 'https' not in word.lower()
            and 'http' not in word.lower()
            and '#' not in word.lower()
            )
        return accepted

    def get_terms(self, tree):
        for leaf in self.leaves(tree):
            term = [ self.normalise(w) for w,t in leaf if self.acceptable_word(w) ]
            yield term

# %% [markdown]
# Grammatical rule to identify phrases

# %%
sentence_re = r'(?:(?:[A-Z])(?:.[A-Z])+.?)|(?:\w+(?:-\w+)*)|(?:\$?\d+(?:.\d+)?%?)|(?:...|)(?:[][.,;"\'?():-_`])'
grammar = r"""
    NBAR:
        {<NN.*|JJ>*<NN.*>}  # Nouns and Adjectives, terminated with Nouns

    NP:
        {<NBAR>}
        {<NBAR><IN><NBAR>}  # Above, connected with in/of/etc...
"""
chunker = nltk.RegexpParser(grammar)

# %% [markdown]
#  New feature called 'key_phrases', will contain phrases for corresponding tweet

# %%
key_phrases = []
phrase_extract_helper = PhraseExtractHelper()

for index, row in Tweets_df.iterrows():
    toks = nltk.regexp_tokenize(row.tidy_tweets, sentence_re)
    postoks = nltk.tag.pos_tag(toks)
    tree = chunker.parse(postoks)

    terms = phrase_extract_helper.get_terms(tree)
    tweet_phrases = []

    for term in terms:
        if len(term):
            tweet_phrases.append(' '.join(term))

    key_phrases.append(tweet_phrases)

key_phrases[:10]
# Out:
# ...
# [['vuka mwaka',
#   'exclusive amp',
#   'nairobi national park',
#   'nairobi tented camp',
#   ' 2 p night  ■ m eals',
#   'half board',
#   'book',
#   'call'],
#  ['nice staycation',
#   'beautiful boma hotel',
#   'weekend',
#   ' ■ k shs',
#   ' 2 p night  ■ m eals',
#   'bed amp',
#   'breakfast',
#   'book',
#   'call',
#   'staycation'],
#  [' sgr train ride',
#   'taita hill safari resort amp',
#   'spa',
#   'relaxing safari adventure',
#   'tsavo west'],
#  ["dubai shopping  fes tival   it'",
#   'amp',
#   'popular shopping festival',
#   'january'],
#  ['thrilling amp',
#   'experience',
#   'bucket list',
#   ' a b alloon safari',
#   'maasai mara',
#   'rate',
#   '$350',
#   'person',
#   'kenyan resident',
#   'hour ride',
#   'champagne breakfast'],
#  ['new year  maa sai mara  tip ilikwani  mar a camp  ■ k',
#   'person',
#   'van  ■ k shs',
#   'person',
#   'cruiser includes',
#   ' 2 n ights stay',
#   'full board',
#   'transport',
#   'game drive park fee',
# ...

# %% [markdown]
# Adding the key phrases extracted to our Dataframe

# %%
Tweets_df['key_phrases'] = key_phrases
Tweets_df.head(10)
# Out:
#    Unnamed: 0       Username  \
# 0           0  trippygotours
# 1           1  trippygotours
# 2           2  trippygotours
# 3           3  trippygotours
# 4           4  trippygotours
# 5           5  trippygotours
# 6           6  trippygotours
# 7           7       linahMVC
# 8           8  trippygotours
# 9           9  trippygotours
#
#                                              Content  \
# 0  Vuka mwaka at the exclusive &amp; only camp in...
# 1  You deserve a nice staycation \n\nWhy not esca...
# 2  Catch the SGR train ride to the Taita Hills Sa...
# 3  DUBAI SHOPPING FESTIVAL 🎉\n\nIt's back, bigger...
# 4  A thrilling &amp; exciting experience you shou...
# 5  NEW YEAR IN MAASAI MARA\n\nTIPILIKWANI MARA CA...
# 6  @linahMVC These are the extra charges to carte...
# 7  @trippygotours What does, supplement 3000 pp p...
# 8  Adults Only Camp\n\nThe Cliff Nakuru is the pe...
# 9  Maasai Mara New Year Safari\n\nMara Serena Saf...
#
#                         Date  \
# ...

# %% [markdown]
# Story Generation and Visualization

# %%
def generate_wordcloud(all_words):
    wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=100, relative_scaling=0.5, colormap='Dark2').generate(all_words)

    plt.figure(figsize=(14, 10))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis('off')
    plt.show()

# %% [markdown]
# Most common words in positive tweets

# %%
from wordcloud import WordCloud

all_words = ' '.join([text for text in Tweets_df['absolute_tidy_tweets'][Tweets_df.sentiment_type == 'Positive']])
generate_wordcloud(all_words)

# %%
import itertools
import collections
all_words_no_url = list(itertools.chain(* [text for text in Tweets_df['key_phrases'][Tweets_df.sentiment_type == 'Positive']]))
counts_positive = collections.Counter(all_words_no_url)
counts_positive.most_common(15)
# Out:
# [('book', 877),
#  ('person', 760),
#  ('call', 660),
#  ('day', 459),
#  ('kenya', 325),
#  ('com', 309),
#  ('holiday', 302),
#  ('deal', 293),
#  ('amp', 280),
#  ('meal', 278),
#  ('per person', 253),
#  ('year', 247),
#  ('trip', 241),
#  ('time', 241),
#  ('thank', 238)]

# %%
clean_positive = pd.DataFrame(counts_positive.most_common(15),
                            columns=["words", "count"])
clean_positive.head(15)
# Out:
#          words  count
# 0         book    877
# 1       person    760
# 2         call    660
# 3          day    459
# 4        kenya    325
# 5          com    309
# 6      holiday    302
# 7         deal    293
# 8          amp    280
# 9         meal    278
# 10  per person    253
# 11        year    247
# 12        trip    241
# 13        time    241
# 14       thank    238

# %%
clean_positive = pd.DataFrame(counts_positive.most_common(15),
                             columns=['words', 'count'])

fig, ax = plt.subplots(figsize=(8, 8))

# Plot horizontal bar graph
clean_positive.sort_values(by='count').plot.barh(x='words',
                      y='count',
                      ax=ax,
                      color="purple")

ax.set_title("Common Words Found in Positive Tweets")

plt.show()

# %% [markdown]
# Most common words in negative tweets

# %%
all_words = ' '.join([text for text in Tweets_df['absolute_tidy_tweets'][Tweets_df.sentiment_type == 'Negative']])
generate_wordcloud(all_words)

# %%
import itertools
import collections
all_words_no_url = list(itertools.chain(* [text for text in Tweets_df['key_phrases'][Tweets_df.sentiment_type == 'Negative']]))
counts_negative = collections.Counter(all_words_no_url)
counts_negative.most_common(15)
# Out:
# [('book', 52),
#  ('amp', 46),
#  ('people', 46),
#  ('day', 45),
#  ('money', 45),
#  ('client', 45),
#  ('com', 40),
#  ('time', 39),
#  ('company', 39),
#  ('night', 36),
#  ('call', 35),
#  ('ksh', 35),
#  ('person', 31),
#  ('business', 31),
#  ('way', 29)]

# %%
clean_negative = pd.DataFrame(counts_negative.most_common(15),
                            columns=["words", "count"])
clean_negative.head(15)
# Out:
#        words  count
# 0       book     52
# 1        amp     46
# 2     people     46
# 3        day     45
# 4      money     45
# 5     client     45
# 6        com     40
# 7       time     39
# 8    company     39
# 9      night     36
# 10      call     35
# 11       ksh     35
# 12    person     31
# 13  business     31
# 14       way     29

# %%
clean_negative = pd.DataFrame(counts_negative.most_common(15),
                             columns=['words', 'count'])

fig, ax = plt.subplots(figsize=(8, 8))

# Plot horizontal bar graph
clean_negative.sort_values(by='count').plot.barh(x='words',
                      y='count',
                      ax=ax,
                      color="purple")

ax.set_title("Common Words Found in negative Tweets")

plt.show()

# %% [markdown]
# Most common words in neutral tweets

# %%
all_words = ' '.join([text for text in Tweets_df['absolute_tidy_tweets'][Tweets_df.sentiment_type == 'Neutral']])
generate_wordcloud(all_words)

# %%
import itertools
import collections
all_words_no_url = list(itertools.chain(* [text for text in Tweets_df['key_phrases'][Tweets_df.sentiment_type == 'Neutral']]))
counts_neutral = collections.Counter(all_words_no_url)
counts_neutral.most_common(15)
# Out:
# [('com', 369),
#  ('deal', 223),
#  ('day', 188),
#  ('call', 158),
#  ('𝐂𝐚𝐥𝐥 𝐖𝐡𝐚𝐭𝐬𝐀𝐩𝐩', 154),
#  ('book', 151),
#  ('meal', 111),
#  ('kenya kenyan seekenya igkenya kenyan', 109),
#  ('kenya', 108),
#  ('pps', 95),
#  ('ksh', 93),
#  ('night', 92),
#  ('bonfiredeals', 90),
#  ('accommodation', 81),
#  ('rate', 71)]

# %%
clean_neutral = pd.DataFrame(counts_neutral.most_common(15),
                            columns=["words", "count"])
clean_neutral.head(15)
# Out:
#                                    words  count
# 0                                    com    369
# 1                                   deal    223
# 2                                    day    188
# 3                                   call    158
# 4                          𝐂𝐚𝐥𝐥 𝐖𝐡𝐚𝐭𝐬𝐀𝐩𝐩    154
# 5                                   book    151
# 6                                   meal    111
# 7   kenya kenyan seekenya igkenya kenyan    109
# 8                                  kenya    108
# 9                                    pps     95
# 10                                   ksh     93
# 11                                 night     92
# 12                          bonfiredeals     90
# 13                         accommodation     81
# 14                                  rate     71

# %%
clean_neutral = pd.DataFrame(counts_neutral.most_common(15),
                             columns=['words', 'count'])

fig, ax = plt.subplots(figsize=(8, 8))

# Plot horizontal bar graph
clean_neutral.sort_values(by='count').plot.barh(x='words',
                      y='count',
                      ax=ax,
                      color="purple")

ax.set_title("Common Words Found in neutral Tweets")

plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 119810 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 119834 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 119845 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 119830 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 119841 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
a = Tweets_df['absolute_tidy_tweets'].str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(a)
word_dist = nltk.FreqDist(words)
dff = pd.DataFrame(word_dist.most_common(),
                    columns=['Word', 'Frequency'])
dff['Word_Count'] = dff.Word.apply(len)
dff[:15]
# Out:
#        Word  Frequency  Word_Count
# 0       amp       2736           3
# 1       The       1928           3
# 2      Kshs       1889           4
# 3      Call       1807           4
# 4         u       1669           1
# 5         I       1610           1
# 6         A       1488           1
# 7        To       1330           2
# 8       day       1258           3
# 9       Per       1218           3
# 10     Book       1165           4
# 11   person       1086           6
# 12      per       1056           3
# 13       We       1032           2
# 14  sharing        956           7

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    print("{:-<40} {}".format(sentence, str(score)))

# %%
#To check and see if the tweets are being classified correctly.
#Checking to see if the algorithm classifys correctly
sentiment_analyzer_scores("☹️")
# Out:
# ☹️-------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
Tweets_df.head()
# Out:
#    Unnamed: 0       Username  \
# 0           0  trippygotours
# 1           1  trippygotours
# 2           2  trippygotours
# 3           3  trippygotours
# 4           4  trippygotours
#
#                                              Content  \
# 0  Vuka mwaka at the exclusive &amp; only camp in...
# 1  You deserve a nice staycation \n\nWhy not esca...
# 2  Catch the SGR train ride to the Taita Hills Sa...
# 3  DUBAI SHOPPING FESTIVAL 🎉\n\nIt's back, bigger...
# 4  A thrilling &amp; exciting experience you shou...
#
#                         Date  \
# 0  2022-12-30 13:03:04+00:00
# 1  2022-12-30 11:51:54+00:00
# 2  2022-12-30 11:32:15+00:00
# 3  2022-12-30 07:51:23+00:00
# 4  2022-12-29 13:17:07+00:00
#
#                                               scores  compound sentiment_type  \
# 0  {'neg': 0.0, 'neu': 0.951, 'pos': 0.049, 'comp...    0.1280       Positive
# 1  {'neg': 0.042, 'neu': 0.773, 'pos': 0.185, 'co...    0.7337       Positive
# ...

# %%
Tweets_df.to_csv('Final.csv', index=False)
